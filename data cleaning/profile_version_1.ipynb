# %%
import pandas as pd

# %% [markdown]
# #### Nous avons voulu garder la date au début du projet avec la colonne "became_member_on" mais on s'est rendu compte que ça n'allait pas être utile pour la suite du projet

# %%
df_profile = pd.read_csv("profile.csv")

# %%
df_profile.head(10)
# Out:
#    Unnamed: 0 gender  age                                id  became_member_on  \
# 0           0    NaN  118  68be06ca386d4c31939f3a4f0e3dd783          20170212
# 1           1      F   55  0610b486422d4921ae7d2bf64640c50b          20170715
# 2           2    NaN  118  38fe809add3b4fcf9315a9694bb96ff5          20180712
# 3           3      F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509
# 4           4    NaN  118  a03223e636434f42ac4c3df47e8bac43          20170804
# 5           5      M   68  e2127556f4f64592b11af22de27a7932          20180426
# 6           6    NaN  118  8ec6ce2a7e7949b1bf142def7d0e0586          20170925
# 7           7    NaN  118  68617ca6246f4fbc85e91a2a49552598          20171002
# 8           8      M   65  389bc3fa690240e798340f5a15918d5c          20180209
# 9           9    NaN  118  8974fc5686fe429db53ddde067b88302          20161122
#
#      income
# 0       NaN
# 1  112000.0
# 2       NaN
# 3  100000.0
# 4       NaN
# 5   70000.0
# 6       NaN
# ...

# %%
df_profile.describe()
# Out:
#          Unnamed: 0           age  became_member_on         income
# count  17000.000000  17000.000000      1.700000e+04   14825.000000
# mean    8499.500000     62.531412      2.016703e+07   65404.991568
# std     4907.621624     26.738580      1.167750e+04   21598.299410
# min        0.000000     18.000000      2.013073e+07   30000.000000
# 25%     4249.750000     45.000000      2.016053e+07   49000.000000
# 50%     8499.500000     58.000000      2.017080e+07   64000.000000
# 75%    12749.250000     73.000000      2.017123e+07   80000.000000
# max    16999.000000    118.000000      2.018073e+07  120000.000000

# %%
df_profile['gender'].isna()
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 16995    False
# 16996    False
# 16997    False
# 16998    False
# 16999    False
# Name: gender, Length: 17000, dtype: bool

# %%
index_with_nan = df_profile.index[df_profile.iloc[:,1].isnull()]

df_profile.drop(index_with_nan,0, inplace=True)

print(df_profile)
# Out:
#        Unnamed: 0 gender  age                                id  \
# 1               1      F   55  0610b486422d4921ae7d2bf64640c50b
# 3               3      F   75  78afa995795e4d85b5d9ceeca43f5fef
# 5               5      M   68  e2127556f4f64592b11af22de27a7932
# 8               8      M   65  389bc3fa690240e798340f5a15918d5c
# 12             12      M   58  2eeac8d8feae4a8cad5a6af0499a211d
# ...           ...    ...  ...                               ...
# 16995       16995      F   45  6d5f3a774f3d4714ab0c092238f3a1d7
# 16996       16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77
# 16997       16997      M   49  01d26f638c274aa0b965d24cefe3183f
# 16998       16998      F   83  9dc1421481194dcd9400aec7c9ae6366
# 16999       16999      F   62  e4052622e5ba45a8b96b59aba68cf068
#
#        became_member_on    income
# 1              20170715  112000.0
# 3              20170509  100000.0
# 5              20180426   70000.0
# 8              20180209   53000.0
# ...

# %%
df_profile
# Out:
#        Unnamed: 0 gender  age                                id  \
# 1               1      F   55  0610b486422d4921ae7d2bf64640c50b
# 3               3      F   75  78afa995795e4d85b5d9ceeca43f5fef
# 5               5      M   68  e2127556f4f64592b11af22de27a7932
# 8               8      M   65  389bc3fa690240e798340f5a15918d5c
# 12             12      M   58  2eeac8d8feae4a8cad5a6af0499a211d
# ...           ...    ...  ...                               ...
# 16995       16995      F   45  6d5f3a774f3d4714ab0c092238f3a1d7
# 16996       16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77
# 16997       16997      M   49  01d26f638c274aa0b965d24cefe3183f
# 16998       16998      F   83  9dc1421481194dcd9400aec7c9ae6366
# 16999       16999      F   62  e4052622e5ba45a8b96b59aba68cf068
#
#        became_member_on    income
# 1              20170715  112000.0
# 3              20170509  100000.0
# 5              20180426   70000.0
# 8              20180209   53000.0
# ...

# %%
df_profile['date'] = pd.to_datetime(df_profile['became_member_on'],format='%Y%m%d')

# %%
df_profile
# Out:
#        Unnamed: 0 gender  age                                id  \
# 1               1      F   55  0610b486422d4921ae7d2bf64640c50b
# 3               3      F   75  78afa995795e4d85b5d9ceeca43f5fef
# 5               5      M   68  e2127556f4f64592b11af22de27a7932
# 8               8      M   65  389bc3fa690240e798340f5a15918d5c
# 12             12      M   58  2eeac8d8feae4a8cad5a6af0499a211d
# ...           ...    ...  ...                               ...
# 16995       16995      F   45  6d5f3a774f3d4714ab0c092238f3a1d7
# 16996       16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77
# 16997       16997      M   49  01d26f638c274aa0b965d24cefe3183f
# 16998       16998      F   83  9dc1421481194dcd9400aec7c9ae6366
# 16999       16999      F   62  e4052622e5ba45a8b96b59aba68cf068
#
#        became_member_on    income       date
# 1              20170715  112000.0 2017-07-15
# 3              20170509  100000.0 2017-05-09
# 5              20180426   70000.0 2018-04-26
# ...

# %%
df_profile.dtypes
# Out:
# Unnamed: 0                   int64
# gender                      object
# age                          int64
# id                          object
# became_member_on             int64
# income                     float64
# date                datetime64[ns]
# dtype: object

# %%
df_profile.describe()
# Out:
#          Unnamed: 0           age  became_member_on         income
# count  14825.000000  14825.000000      1.482500e+04   14825.000000
# mean    8496.961079     54.393524      2.016689e+07   65404.991568
# std     4896.261043     17.383705      1.188565e+04   21598.299410
# min        1.000000     18.000000      2.013073e+07   30000.000000
# 25%     4273.000000     42.000000      2.016052e+07   49000.000000
# 50%     8490.000000     55.000000      2.017080e+07   64000.000000
# 75%    12733.000000     66.000000      2.017123e+07   80000.000000
# max    16999.000000    101.000000      2.018073e+07  120000.000000

# %%
print(df_profile.isna().sum())
# Out:
# Unnamed: 0          0
# gender              0
# age                 0
# id                  0
# became_member_on    0
# income              0
# date                0
# dtype: int64

# %%
df_profile['age'].unique()
# Out:
# array([ 55,  75,  68,  65,  58,  61,  26,  62,  49,  57,  40,  64,  78,
#         42,  56,  33,  46,  59,  67,  53,  22,  96,  69,  20,  45,  54,
#         39,  41,  79,  66,  29,  44,  63,  36,  76,  77,  30,  51,  27,
#         73,  74,  70,  89,  50,  90,  60,  19,  72,  52,  18,  71,  83,
#         43,  47,  32,  38,  34,  85,  48,  35,  82,  21,  24,  81,  25,
#         37,  23, 100,  28,  84,  80,  87,  86,  94,  31,  88,  95,  93,
#         91,  92,  98, 101,  97,  99], dtype=int64)

# %%
df_profile.drop('Unnamed: 0', axis=1)
# Out:
#       gender  age                                id  became_member_on  \
# 1          F   55  0610b486422d4921ae7d2bf64640c50b          20170715
# 3          F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509
# 5          M   68  e2127556f4f64592b11af22de27a7932          20180426
# 8          M   65  389bc3fa690240e798340f5a15918d5c          20180209
# 12         M   58  2eeac8d8feae4a8cad5a6af0499a211d          20171111
# ...      ...  ...                               ...               ...
# 16995      F   45  6d5f3a774f3d4714ab0c092238f3a1d7          20180604
# 16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77          20180713
# 16997      M   49  01d26f638c274aa0b965d24cefe3183f          20170126
# 16998      F   83  9dc1421481194dcd9400aec7c9ae6366          20160307
# 16999      F   62  e4052622e5ba45a8b96b59aba68cf068          20170722
#
#          income       date
# 1      112000.0 2017-07-15
# 3      100000.0 2017-05-09
# 5       70000.0 2018-04-26
# ...

# %%
Indexgender = df_profile[df_profile['gender'] == 'O'].index

# %%
df_profile.drop(Indexgender, inplace=True)

# %%
df_profile['gender'].value_counts()
# Out:
# M    8484
# F    6129
# Name: gender, dtype: int64

# %%
df_profile.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df_profile['member'] = df_profile['became_member_on'].apply(lambda x: 1 if x != '' else 0)

# %%
df_profile
# Out:
#       gender  age                                id  became_member_on  \
# 1          F   55  0610b486422d4921ae7d2bf64640c50b          20170715
# 3          F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509
# 5          M   68  e2127556f4f64592b11af22de27a7932          20180426
# 8          M   65  389bc3fa690240e798340f5a15918d5c          20180209
# 12         M   58  2eeac8d8feae4a8cad5a6af0499a211d          20171111
# ...      ...  ...                               ...               ...
# 16995      F   45  6d5f3a774f3d4714ab0c092238f3a1d7          20180604
# 16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77          20180713
# 16997      M   49  01d26f638c274aa0b965d24cefe3183f          20170126
# 16998      F   83  9dc1421481194dcd9400aec7c9ae6366          20160307
# 16999      F   62  e4052622e5ba45a8b96b59aba68cf068          20170722
#
#          income       date  member
# 1      112000.0 2017-07-15       1
# 3      100000.0 2017-05-09       1
# ...

# %%
df_profile_ml = pd.DataFrame(zip(df_profile.gender,df_profile.age,df_profile.income,df_profile.member))

# %%
df_profile_ml.columns = ['gender', 'age', 'income', 'member']

# %%
df_profile_ml
# Out:
#       gender  age    income  member
# 0          F   55  112000.0       1
# 1          F   75  100000.0       1
# 2          M   68   70000.0       1
# 3          M   65   53000.0       1
# 4          M   58   51000.0       1
# ...      ...  ...       ...     ...
# 14608      F   45   54000.0       1
# 14609      M   61   72000.0       1
# 14610      M   49   73000.0       1
# 14611      F   83   50000.0       1
# 14612      F   62   82000.0       1
#
# [14613 rows x 4 columns]

# %%
df_profile_ml.to_csv("profil_ml_member.csv", index=False)

# %%
# df_profile['member'] = df_profile['date'].apply(lambda x: '1' if == format'%Y%m%d' else '0')

# %%
mask = df_profile['gender'] == 'M'
df_homme = df_profile.loc[mask, :]
df_homme
# Out:
#        Unnamed: 0 gender  age                                id  \
# 5               5      M   68  e2127556f4f64592b11af22de27a7932
# 8               8      M   65  389bc3fa690240e798340f5a15918d5c
# 12             12      M   58  2eeac8d8feae4a8cad5a6af0499a211d
# 14             14      M   26  e12aeaf2d47d42479ea1c4ac3d8286c6
# 16             16      M   49  62cf5e10845442329191fc246e7bcea3
# ...           ...    ...  ...                               ...
# 16987       16987      M   57  76ddbd6576844afe811f1a3c0fbb5bec
# 16988       16988      M   64  f653cf2d8bba42d0a53c2937ee2e5893
# 16993       16993      M   60  cb23b66c56f64b109d673d5e56574529
# 16996       16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77
# 16997       16997      M   49  01d26f638c274aa0b965d24cefe3183f
#
#        became_member_on    income       date    member
# 5              20180426   70000.0 2018-04-26  20180426
# 8              20180209   53000.0 2018-02-09  20180209
# ...

# %%
df_homme.drop('Unnamed: 0', axis=1)
# Out:
#       gender  age                                id  became_member_on  \
# 5          M   68  e2127556f4f64592b11af22de27a7932          20180426
# 8          M   65  389bc3fa690240e798340f5a15918d5c          20180209
# 12         M   58  2eeac8d8feae4a8cad5a6af0499a211d          20171111
# 14         M   26  e12aeaf2d47d42479ea1c4ac3d8286c6          20140213
# 16         M   49  62cf5e10845442329191fc246e7bcea3          20141113
# ...      ...  ...                               ...               ...
# 16987      M   57  76ddbd6576844afe811f1a3c0fbb5bec          20160709
# 16988      M   64  f653cf2d8bba42d0a53c2937ee2e5893          20180104
# 16993      M   60  cb23b66c56f64b109d673d5e56574529          20180505
# 16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77          20180713
# 16997      M   49  01d26f638c274aa0b965d24cefe3183f          20170126
#
#          income       date    member
# 5       70000.0 2018-04-26  20180426
# 8       53000.0 2018-02-09  20180209
# ...

# %%
df_homme.drop('member', axis=1)
# Out:
#        Unnamed: 0 gender  age                                id  \
# 5               5      M   68  e2127556f4f64592b11af22de27a7932
# 8               8      M   65  389bc3fa690240e798340f5a15918d5c
# 12             12      M   58  2eeac8d8feae4a8cad5a6af0499a211d
# 14             14      M   26  e12aeaf2d47d42479ea1c4ac3d8286c6
# 16             16      M   49  62cf5e10845442329191fc246e7bcea3
# ...           ...    ...  ...                               ...
# 16987       16987      M   57  76ddbd6576844afe811f1a3c0fbb5bec
# 16988       16988      M   64  f653cf2d8bba42d0a53c2937ee2e5893
# 16993       16993      M   60  cb23b66c56f64b109d673d5e56574529
# 16996       16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77
# 16997       16997      M   49  01d26f638c274aa0b965d24cefe3183f
#
#        became_member_on    income       date
# 5              20180426   70000.0 2018-04-26
# 8              20180209   53000.0 2018-02-09
# 12             20171111   51000.0 2017-11-11
# ...

# %%
df_homme['groupe_age_h'] = df_homme['age']

# %%
mask = df_profile['gender'] == 'F'
df_femme = df_profile.loc[mask, :]
df_femme
# Out:
#        Unnamed: 0 gender  age                                id  \
# 1               1      F   55  0610b486422d4921ae7d2bf64640c50b
# 3               3      F   75  78afa995795e4d85b5d9ceeca43f5fef
# 13             13      F   61  aa4862eba776480b8bb9c68455b8c2e1
# 15             15      F   62  31dda685af34476cad5bc968bdb01c53
# 19             19      F   61  a448667f336b42c9a66fc5ffd5d73772
# ...           ...    ...  ...                               ...
# 16990       16990      F   70  79edb810789c447e8d212a324b44cc16
# 16992       16992      F   21  400d0536e8794cbb855b0d882d67cbda
# 16995       16995      F   45  6d5f3a774f3d4714ab0c092238f3a1d7
# 16998       16998      F   83  9dc1421481194dcd9400aec7c9ae6366
# 16999       16999      F   62  e4052622e5ba45a8b96b59aba68cf068
#
#        became_member_on    income       date    member
# 1              20170715  112000.0 2017-07-15  20170715
# 3              20170509  100000.0 2017-05-09  20170509
# ...
